# %% [markdown]
# <커피 자판기 만들기>
#
# -금액 투입
# -커피 선택
# -커피 출력 (커피가 없으면 "품절" 출력)
# -잔액 출력
# -금액 :1000, 500,100투입
#
# *관리자/ 사용자 기능 구현
# -관리자
# 커피 재료 (10잔 입력)
# 동전 투입(1000-30장, 500-20개, 100-50개)
#
# -사용자
# 금액 투입
# 커피 선택
# 잔액 출력 => 잔액 출력 or 커피를 추가적으로 선택
#
#
# ex)
#
# step1. "선택하세요. (1) 관리자 모드 (2)사용자 모드 (3)종료"
# 입력 :1
#
# #관리자 모드
# step2. "(1)커피 재료 (2)금액 투입 (3)종료" **(3)종료는 처음 단계로
# 입력:1
#
# step3.
# 커피 충전 입력 : 10
# 10잔이 충전되었습니다.
#
# -------------------------------------------------------------
# #사용자 모드
# 입력:2
#
# step2. "금액 투입"
#
# step3. "커피 선택"
#
# step4: "잔액 출력"
#
# step5: "잔액 출력" or "커피 추가 선택"

# %%
Selection=int(input("선택하시오: 1.관리자 모드 2.사용자 모드 3.종료\n"))  #초기 선택 화면
coffee_total=0
coffee=0
money=0

while Selection==1: #관리자 모드 선택
    Selection1_1=int(input("선택하시오: 1.커피투입 2.금액투입 3.종료\n")) #관리자 모드_기능구현
    if Selection1_1==1:   #커피 충전
        coffee=int(input())
        coffee_total+=coffee
        print("커피가 충전되었습니다. 총 커피의 갯수는 %d 입니다." %coffee_total)
           
    elif Selection1_1==2:   #금액 충전 (1000원 . 500원, 100원별로)
                cnt_t=int(input())
                cnt_f=int(input())
                cnt_o=int(input())

                money_t=1000*cnt_t
                money_f=500*cnt_f
                money_o=100*cnt_o
                
                money_total=money_t+money_f+money_o
                print("금액이 충전되었습니다. 총 충전된 금액은 %d 입니다." %money_total)
            
                            
    elif Selection1_1==3: 
        
        
while Selection==2: #사용자 모드
    money= int(input("금액을 넣어 주세요:  "))
    coffee= int(input("원하시는 커피의 수량을 눌러주세요: "))

    if money<300:
        print("돈을 더 넣어주세요.")
        money= int(input("금액을 넣어 주세요:  "))
        coffee= int(input("원하시는 커피의 수량을 눌러주세요: "))

    elif coffee==0:
        print("원하시는 커피의 수량을 다시 눌러주세요.")
        money= int(input("금액을 넣어 주세요:  "))
        coffee= int(input("원하시는 커피의 수량을 눌러주세요: "))

    while money>=300 and coffee>=1: 
        print("커피가 나옵니다.")
        money=money-300
        coffee=coffee-1
        print("남은 금액은 %d 입니다." %money)
        print("남은 커피는 %d 입니다." %coffee)
            
        if money<300:
                print("돈을 더 넣어주세요.")
                Selection2_1=int(input("선택하시오: 1.잔액 받기 2.금액 추가\n"))
                if Selection2_1==1:
                    print("잔액은 %d 입니다." %money)
                    break
                elif Selection2_1==2:
                    add_money=int(input())
                    money=money+add_money
                    print("금액이 충전되었습니다. 잔액은 %d 입니다." %money)
            
        elif coffee==0:
                print("커피가 다 나왔습니다. 판매를 중단합니다.")
                print("잔액은 %d입니다." %money)
                break
# Out:
# 선택하시오: 1.관리자 모드 2.사용자 모드 3.종료
# 3
