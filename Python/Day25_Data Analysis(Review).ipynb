# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action="ignore")

# %%
df=pd.read_csv("gapminder.tsv",sep="\t")
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
subset=df[["country", "continent","year"]]
subset
# Out:
#           country continent  year
# 0     Afghanistan      Asia  1952
# 1     Afghanistan      Asia  1957
# 2     Afghanistan      Asia  1962
# 3     Afghanistan      Asia  1967
# 4     Afghanistan      Asia  1972
# ...           ...       ...   ...
# 1699     Zimbabwe    Africa  1987
# 1700     Zimbabwe    Africa  1992
# 1701     Zimbabwe    Africa  1997
# 1702     Zimbabwe    Africa  2002
# 1703     Zimbabwe    Africa  2007
#
# [1704 rows x 3 columns]

# %%
df.head(n=10)
df.tail() #default: n=5
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.loc[[0,100,1000]] #행 추출
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 100    Bangladesh      Asia  1972   45.252  70759295   630.233627
# 1000     Mongolia      Asia  1972   53.754   1320500  1421.741975

# %%
df[["year","pop"]]
df.loc[:,["year","pop"]]
df.iloc[:,[2,4]]
df.iloc[:, list(range(5))]
# Out:
#           country continent  year  lifeExp       pop
# 0     Afghanistan      Asia  1952   28.801   8425333
# 1     Afghanistan      Asia  1957   30.332   9240934
# 2     Afghanistan      Asia  1962   31.997  10267083
# 3     Afghanistan      Asia  1967   34.020  11537966
# 4     Afghanistan      Asia  1972   36.088  13079460
# ...           ...       ...   ...      ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418
# 1700     Zimbabwe    Africa  1992   60.377  10704340
# 1701     Zimbabwe    Africa  1997   46.809  11404948
# 1702     Zimbabwe    Africa  2002   39.989  11926563
# 1703     Zimbabwe    Africa  2007   43.487  12311143
#
# [1704 rows x 5 columns]

# %%
df.year.unique()
#연도별 기대수명의 평균

df.groupby("year")["lifeExp"].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby(["year","continent"])[["lifeExp","gdpPercap"]].mean() #year에 따라 continent별로 lifeExp / gdpPercap에 대한 평균
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
df.groupby("year")["lifeExp"].nunique() #그룹화한 데이터 갯수

df.groupby("continent")["country"].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
gle=df.groupby("year")["lifeExp"].mean()
gle.plot()

# %%
s=pd.Series(["apple",30],index=["Name","Num"])
s.loc["Num"]
s.iloc[1]
# Out:
# 30

# %%
df=pd.DataFrame({
    "Name" : ["AAA","BBB"],
    "Age" : [20,30]    
},index=["first","second"])  #index지정 

df
first_row=df.loc["first"]
first_row.index
first_row.keys()
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
ages=df["Age"]
ages.mean()
# Out:
# 25.0

# %%
scientists=pd.read_csv("scientists.csv")
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
ages=scientists["Age"]

# %%
scientists[ages>ages.mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
ages.sort_index(ascending=False)
ages.sort_values(ascending=True)

rev_ages=ages.sort_index(ascending=True)

# %%
print(ages)
print(rev_ages)
print(ages+rev_ages) #같은 index끼리 연산됨
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
scientists[scientists["Age"]>scientists["Age"].mean()]


scientists["Born"].dtypes
bd=pd.to_datetime(scientists["Born"], format="%Y-%m-%d") #datetime으로 변경 (format지정)
dd=pd.to_datetime(scientists["Died"], format="%Y-%m-%d")

# %%
scientists["bd"],scientists["dd"]=bd,dd

# %%
scientists["bt"]=scientists["bd"]-scientists["dd"]
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#           bd         dd          bt
# 0 1920-07-25 1958-04-16 -13779 days
# 1 1876-06-13 1937-10-16 -22404 days
# 2 1820-05-12 1910-08-13 -32964 days
# 3 1867-11-07 1934-07-04 -24345 days
# 4 1907-05-27 1964-04-14 -20777 days
# 5 1813-03-15 1858-06-16 -16529 days
# 6 1912-06-23 1954-06-07 -15324 days
# ...

# %%
import random
random.shuffle(scientists["Age"]) #shuffle: 값 랜덤
print(scientists["Age"])
# Out:
# 0    37
# 1    90
# 2    66
# 3    56
# 4    77
# 5    61
# 6    45
# 7    41
# Name: Age, dtype: int64

# %%
#피클로 저장: 데이터 객체를 그대로 저장 (데이터프레임이든 시리즈든 저장 가능)

#객체 그대로 저장하기 때문에 데이터가 가벼움 

names=scientists["Name"]
names.to_pickle("sci_name.pickle")

# %%
sci_name_fp=pd.read_pickle("sci_name.pickle")
sci_name_fp
# Out:
# 0       Rosaline Franklin
# 1          William Gosset
# 2    Florence Nightingale
# 3             Marie Curie
# 4           Rachel Carson
# 5               John Snow
# 6             Alan Turing
# 7            Johann Gauss
# Name: Name, dtype: object

# %%
#엑셀로 저장

scientists.to_excel("sci.xls")

# %% [markdown]
# ## dataframe 합치기

# %% [markdown]
# ### concat

# %%
df1=pd.read_csv("concat_1.csv")
df2=pd.read_csv("concat_2.csv")
df3=pd.read_csv("concat_3.csv")

# %%
rc=pd.concat([df1,df2,df3])
rc
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
rc.iloc[3] #3번 인덱스 추출(본 인덱스 기준으로)
# Out:
# A    a3
# B    b3
# C    c3
# D    d3
# Name: 3, dtype: object

# %%
rc.loc[3]
# Out:
#      A    B    C    D
# 3   a3   b3   c3   d3
# 3   a7   b7   c7   d7
# 3  a11  b11  c11  d11

# %%
nrdf=pd.DataFrame([["n1","n2","n3","n4"]], columns=["A","B","C","D"])
nrdf
# Out:
#     A   B   C   D
# 0  n1  n2  n3  n4

# %%
# df + series: 아래로 합쳐지기 때문에 df1에는 NaN이 채워짐 **

pd.concat([df1,nrdf])  #df+df : columns을 맞춰주면 하나로 합쳐짐
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 0  n1  n2  n3  n4

# %%
myDict={"A":"n1","B":"n2","C":"n3","D":"n4"}
df1.append(myDict, ignore_index=True)
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  n1  n2  n3  n4

# %%
rci=pd.concat([df1,df2,df3],ignore_index=True)
rci
# Out:
#       A    B    C    D
# 0    a0   b0   c0   d0
# 1    a1   b1   c1   d1
# 2    a2   b2   c2   d2
# 3    a3   b3   c3   d3
# 4    a4   b4   c4   d4
# 5    a5   b5   c5   d5
# 6    a6   b6   c6   d6
# 7    a7   b7   c7   d7
# 8    a8   b8   c8   d8
# 9    a9   b9   c9   d9
# 10  a10  b10  c10  d10
# 11  a11  b11  c11  d11

# %%
#열방향으로 데이터프레임 연결
cc=pd.concat([df1,df2,df3],axis=1)
cc
# Out:
#     A   B   C   D   A   B   C   D    A    B    C    D
# 0  a0  b0  c0  d0  a4  b4  c4  d4   a8   b8   c8   d8
# 1  a1  b1  c1  d1  a5  b5  c5  d5   a9   b9   c9   d9
# 2  a2  b2  c2  d2  a6  b6  c6  d6  a10  b10  c10  d10
# 3  a3  b3  c3  d3  a7  b7  c7  d7  a11  b11  c11  d11

# %%
cc["A"]
cc["ncl"]=["n1","n2","n3","n4"]

# %%
cc
# Out:
#     A   B   C   D   A   B   C   D    A    B    C    D ncl
# 0  a0  b0  c0  d0  a4  b4  c4  d4   a8   b8   c8   d8  n1
# 1  a1  b1  c1  d1  a5  b5  c5  d5   a9   b9   c9   d9  n2
# 2  a2  b2  c2  d2  a6  b6  c6  d6  a10  b10  c10  d10  n3
# 3  a3  b3  c3  d3  a7  b7  c7  d7  a11  b11  c11  d11  n4

# %%
#반복되는 열 제거
pd.concat([df1,df2,df3],axis=1)

# %%
df1.columns=["A","B","C","D"]

df2.columns=["E","F","G","H"]
df2
df3.columns=["A","C","F","H"]

# df3

# %%
pd.concat([df1,df2,df3], join="inner") #공통열만 합침(교집합)

df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
pd.concat([df1,df3], join="inner")
# Out:
#      A    C
# 0   a0   c0
# 1   a1   c1
# 2   a2   c2
# 3   a3   c3
# 0   a8   b8
# 1   a9   b9
# 2  a10  b10
# 3  a11  b11

# %%
df2.index=[4,5,6,7]
df3.index=[0,2,5,7]

# %%
df3
# Out:
#      A    C    F    H
# 0   a8   b8   c8   d8
# 2   a9   b9   c9   d9
# 5  a10  b10  c10  d10
# 7  a11  b11  c11  d11

# %%
pd.concat([df1,df2,df3],axis=1) #좌우로 연결

pd.concat([df1,df3],axis=1,join="inner")
# Out:
#     A   B   C   D   A   C   F   H
# 0  a0  b0  c0  d0  a8  b8  c8  d8
# 2  a2  b2  c2  d2  a9  b9  c9  d9

# %% [markdown]
# ### merge

# %%
person=pd.read_csv("survey_person.csv")
site=pd.read_csv("survey_site.csv")
survey=pd.read_csv("survey_survey.csv")
visited=pd.read_csv("survey_visited.csv")
visited_subset=visited.loc[[0,2,6],]

# %%
visited_subset
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 2    734   DR-3  1939-01-07
# 6    837  MSK-4  1932-01-14

# %%
site
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40

# %%
o2o=site.merge(visited_subset, left_on="name", right_on="site")
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
visited
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3         NaN
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
m2o=site.merge(visited, left_on="name", right_on="site")
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-1 -49.85 -128.57    622   DR-1  1927-02-10
# 2   DR-1 -49.85 -128.57    844   DR-1  1932-03-22
# 3   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 4   DR-3 -47.15 -126.72    735   DR-3  1930-01-12
# 5   DR-3 -47.15 -126.72    751   DR-3  1930-02-26
# 6   DR-3 -47.15 -126.72    752   DR-3         NaN
# 7  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
person
# Out:
#       ident   personal    family
# 0      dyer    William      Dyer
# 1        pb      Frank   Pabodie
# 2      lake   Anderson      Lake
# 3       roe  Valentina   Roerich
# 4  danforth      Frank  Danforth

# %%
survey
# Out:
#     taken person quant  reading
# 0     619   dyer   rad     9.82
# 1     619   dyer   sal     0.13
# 2     622   dyer   rad     7.80
# 3     622   dyer   sal     0.09
# 4     734     pb   rad     8.41
# 5     734   lake   sal     0.05
# 6     734     pb  temp   -21.50
# 7     735     pb   rad     7.22
# 8     735    NaN   sal     0.06
# 9     735    NaN  temp   -26.00
# 10    751     pb   rad     4.35
# 11    751     pb  temp   -18.50
# 12    751   lake   sal     0.10
# 13    752   lake   rad     2.19
# 14    752   lake   sal     0.09
# 15    752   lake  temp   -16.00
# 16    752    roe   sal    41.60
# 17    837   lake   rad     1.46
# 18    837   lake   sal     0.21
# 19    837    roe   sal    22.50
# 20    844    roe   rad    11.25

# %%
ps=person.merge(survey, left_on="ident", right_on="person")
ps
# Out:
#    ident   personal   family  taken person quant  reading
# 0   dyer    William     Dyer    619   dyer   rad     9.82
# 1   dyer    William     Dyer    619   dyer   sal     0.13
# 2   dyer    William     Dyer    622   dyer   rad     7.80
# 3   dyer    William     Dyer    622   dyer   sal     0.09
# 4     pb      Frank  Pabodie    734     pb   rad     8.41
# 5     pb      Frank  Pabodie    734     pb  temp   -21.50
# 6     pb      Frank  Pabodie    735     pb   rad     7.22
# 7     pb      Frank  Pabodie    751     pb   rad     4.35
# 8     pb      Frank  Pabodie    751     pb  temp   -18.50
# 9   lake   Anderson     Lake    734   lake   sal     0.05
# 10  lake   Anderson     Lake    751   lake   sal     0.10
# 11  lake   Anderson     Lake    752   lake   rad     2.19
# 12  lake   Anderson     Lake    752   lake   sal     0.09
# 13  lake   Anderson     Lake    752   lake  temp   -16.00
# 14  lake   Anderson     Lake    837   lake   rad     1.46
# ...

# %%
vs=visited.merge(survey, left_on="ident", right_on="taken")
vs
# Out:
#     ident   site       dated  taken person quant  reading
# 0     619   DR-1  1927-02-08    619   dyer   rad     9.82
# 1     619   DR-1  1927-02-08    619   dyer   sal     0.13
# 2     622   DR-1  1927-02-10    622   dyer   rad     7.80
# 3     622   DR-1  1927-02-10    622   dyer   sal     0.09
# 4     734   DR-3  1939-01-07    734     pb   rad     8.41
# 5     734   DR-3  1939-01-07    734   lake   sal     0.05
# 6     734   DR-3  1939-01-07    734     pb  temp   -21.50
# 7     735   DR-3  1930-01-12    735     pb   rad     7.22
# 8     735   DR-3  1930-01-12    735    NaN   sal     0.06
# 9     735   DR-3  1930-01-12    735    NaN  temp   -26.00
# 10    751   DR-3  1930-02-26    751     pb   rad     4.35
# 11    751   DR-3  1930-02-26    751     pb  temp   -18.50
# 12    751   DR-3  1930-02-26    751   lake   sal     0.10
# 13    752   DR-3         NaN    752   lake   rad     2.19
# 14    752   DR-3         NaN    752   lake   sal     0.09
# ...

# %%
ti=ps.merge(vs, left_on="taken", right_on="ident")
ti.shape
# Out:
# (55, 14)

# %%
ip=ps.merge(vs, left_on="ident", right_on="person")
ip.shape
# Out:
# (99, 14)

# %%
ps.merge(vs, left_on=["taken","ident"], right_on=["ident","person"])
# Out:
#    ident_x   personal   family  taken_x person_x quant_x  reading_x  ident_y  \
# 0     dyer    William     Dyer      619     dyer     rad       9.82      619
# 1     dyer    William     Dyer      619     dyer     rad       9.82      619
# 2     dyer    William     Dyer      619     dyer     sal       0.13      619
# 3     dyer    William     Dyer      619     dyer     sal       0.13      619
# 4     dyer    William     Dyer      622     dyer     rad       7.80      622
# 5     dyer    William     Dyer      622     dyer     rad       7.80      622
# 6     dyer    William     Dyer      622     dyer     sal       0.09      622
# 7     dyer    William     Dyer      622     dyer     sal       0.09      622
# 8       pb      Frank  Pabodie      734       pb     rad       8.41      734
# 9       pb      Frank  Pabodie      734       pb     rad       8.41      734
# 10      pb      Frank  Pabodie      734       pb    temp     -21.50      734
# ...

# %%
import numpy as np

# %%
np.NaN
# Out:
# nan

# %%
gap=pd.read_csv("gapminder.tsv",sep="\t")

# %%
le=gap.groupby("year")["lifeExp"].mean()
le.loc[range(2000,2010),]
# Out:
# year
# 2000          NaN
# 2001          NaN
# 2002    65.694923
# 2003          NaN
# 2004          NaN
# 2005          NaN
# 2006          NaN
# 2007    67.007423
# 2008          NaN
# 2009          NaN
# Name: lifeExp, dtype: float64

# %%
le[le.index>2000]
# Out:
# year
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df=pd.DataFrame({
    "a":["a1","a1","a2","a2","a3"],
     "b":["b1","b1","b2","b2",np.nan],
     "c":[1,1,3,4,4]   
})

# %%
df['a'].value_counts(normalize=True) #상대비율
df['a'].value_counts(normalize=False) #갯수
# Out:
# a1    2
# a2    2
# a3    1
# Name: a, dtype: int64
